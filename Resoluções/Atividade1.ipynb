# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #**Lista de Exercícios 01**

# %% [markdown]
# 1. Escolha e baixe um conjunto de dados da plataforma Kaggle (https://www.kaggle.com/datasets), que tenha ao menos um atributo numérico. Carregue os dados através da biblioteca Pandas ou Dask.

# %%
df = pd.read_csv('/content/drive/MyDrive/UFC/2021.1/ML/dataset/worldhappiness.data', sep=',')

# %% [markdown]
# 2. Exiba as 20 primeiras linhas do conjunto de dados selecionado.

# %%
df.head(20)
# Out:
#     Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0              1           Finland  ...       0.153                      0.393
# 1              2           Denmark  ...       0.252                      0.410
# 2              3            Norway  ...       0.271                      0.341
# 3              4           Iceland  ...       0.354                      0.118
# 4              5       Netherlands  ...       0.322                      0.298
# 5              6       Switzerland  ...       0.263                      0.343
# 6              7            Sweden  ...       0.267                      0.373
# 7              8       New Zealand  ...       0.330                      0.380
# 8              9            Canada  ...       0.285                      0.308
# 9             10           Austria  ...       0.244                      0.226
# 10            11         Australia  ...       0.332                      0.290
# 11            12        Costa Rica  ...       0.144                      0.093
# 12            13            Israel  ...       0.261                      0.082
# 13            14        Luxembourg  ...       0.194                      0.316
# 14            15    United Kingdom  ...       0.348                      0.278
# 15            16           Ireland  ...       0.298                      0.310
# 16            17           Germany  ...       0.261                      0.265
# 17            18           Belgium  ...       0.160                      0.210
# 18            19     United States  ...       0.280                      0.128
# 19            20    Czech Republic  ...       0.046                      0.036
#
# [20 rows x 9 columns]

# %% [markdown]
# 3. Exiba o número de linhas de dados presentes no conjunto de dados selecionado.

# %%
len(df.index)
# Out:
# 156

# %% [markdown]
# 4. Exiba a média, o desvio padrão, e os valores mínimo e máximo de um campo numérico do conjunto de dados selecionado.

# %%
df2 = pd.Series([df["Score"].mean(), df["Score"].std(), df["Score"].min(), df["Score"].max()], 
                index=["Média", "Desvio padrão","Valor mínimo","Valor máximo"])
print(df2)
# Out:
# Média            5.407096
# Desvio padrão    1.113120
# Valor mínimo     2.853000
# Valor máximo     7.769000
# dtype: float64

# %% [markdown]
# 5. Exiba as 5 primeiras linhas do conjunto de dados ordenado em ordem decrescente pelo mesmo campo numérico usado por você na questão 4.

# %%
df["Score"].sort_values(ascending=False).head(5)
# Out:
# 0    7.769
# 1    7.600
# 2    7.554
# 3    7.494
# 4    7.488
# Name: Score, dtype: float64
